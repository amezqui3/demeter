# %% [markdown]
# # The shape of things to come
#
# ## Topological Data Analysis applied to plant biology
#
# ---
#
# ## Erik Amézquita
#
# Dept. of Computational Mathematics, Science & Engineering ([CMSE](https://cmse.msu.edu/))
#
# Michigan State University
#
# February 2022

# %% [markdown]
# # Welcome
#
# This notebook is meant to be a first step introduction to compute Euler Characteristic Curves and the Euler Characteristic Transform for 2D and 3D images.  This repository includes the jupyter notebooks for the [2022 Annual Meeting of the NAPPN](https://www.plantphenotyping.org/conference-home) to be held virtually, led by [Erik Amézquita](http://egr.msu.edu/~amezqui3). This introduction is tailored for a phenotyping plant biology audience, so the focus is on topological tools for image analysis.
#
# These slides are written to be presented as [RISE slides](https://rise.readthedocs.io/en/stable/index.html), however the notebook should be self contained without needing this installed. If you see a lot of weird cell toolbars in the notebook (which are used for controlling the slideshow version), these can be removed from your view of the jupyter notebook by going to `View -> Cell Toolbar -> None`

# %% [markdown]
# # Plan
#
# 1. Gentle introduction to Topological Data Analysis (TDA)
# 1. A brief overview of TDA software available
# 1. Focus on the Euler characteristic to efficiently extract shape from very large images (both 2D and 3D)
#
#
# # Goal
#
# - Give you a place to start if you want to delve deeper into TDA

# %% [markdown]
# # Options to follow along
#
# - Clone the [github repo](https://github.com/amezqui3/ect_and_barley): `https://github.com/amezqui3/ect_and_barley`
# - Run directly from [**google collab**](https://colab.research.google.com/github/amezqui3/demeter/blob/main/tutorial/nappn2022_shape_of_things_to_come.ipynb): https://colab.research.google.com/github/amezqui3/demeter/blob/main/tutorial/nappn2022_shape_of_things_to_come.ipynb

# %% [markdown]
# # If running from google colab, you might need to load your Drive and add some extra files.
#
# - In your drive, create a folder named `tda_workshop`
# - Inside this folder, copy the contents from this other [folder](https://drive.google.com/drive/folders/1h_bIqrpkzwG9z5S5Q9Bs3zscQSrqPMTB?usp=sharing): https://drive.google.com/drive/folders/1h_bIqrpkzwG9z5S5Q9Bs3zscQSrqPMTB?usp=sharing

# %% [markdown]
# # Quantify and compare all shape diversity
#
# - Data diversity: morphometrics might not be enough

# %%
import IPython.display as display
import ipywidgets as widgets
video1, video2,video3,video4 = widgets.Output(), widgets.Output(),widgets.Output(), widgets.Output()
video5, video6,video7,video8 = widgets.Output(), widgets.Output(),widgets.Output(), widgets.Output()
video11, video12,video13,video14 = widgets.Output(), widgets.Output(),widgets.Output(), widgets.Output()

with video1:
    display.display(display.YouTubeVideo('j0R9mMs5E50', autoplay=True))
with video2:
    display.display(display.YouTubeVideo('4GBgPIEDoa0', autoplay=True))
with video3:
    display.display(display.YouTubeVideo('m5ogcckInwo', autoplay=True))
with video4:
    display.display(display.YouTubeVideo('9ynQ4-NxT3g', autoplay=True))
with video5:
    display.display(display.YouTubeVideo('V39K58evWlU', autoplay=True))
with video6:
    display.display(display.YouTubeVideo('vxcSZsCs5BU', autoplay=True))
with video7:
    display.display(display.YouTubeVideo('2FmwkEA3tsY', autoplay=True))
with video8:
    display.display(display.YouTubeVideo('KXt-C-_OA3o', autoplay=True))
with video11:
    display.display(display.YouTubeVideo('8dF_ZtUTPRk', width=500, heigh=400, autoplay=False))
with video12:
    display.display(display.YouTubeVideo('-XCVn73p3xs', width=500, heigh=400,autoplay=False))
with video13:
    display.display(display.YouTubeVideo('Swlem15nvrc', width=500, heigh=400,autoplay=False))
with video14:
    display.display(display.YouTubeVideo('bR8nmASz3W8', width=500, heigh=400,autoplay=False))

# %%
display.display(widgets.HBox([video1,video2,video3,video4]))

# %% [markdown]
# ## Traditional Morphometry
#
# <img src=https://nph.onlinelibrary.wiley.com/cms/asset/e0e8b362-efee-410a-a293-947c2d57acb9/nph16286-fig-0003-m.jpg width="1000">
#
# Credits: [Gupta _et al_ (2019)](https://doi.org/10.1111/nph.16286)

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
# ## Geometric Morphometrics may not be enough
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <p style="text-align:center;font-size:24px"><strong>Elliptic Fourier Descriptors (EFD)</strong></p>
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/chitwood_sinha_2016_01_02.jpg" alt = "barley" style="width:500px;"/>
#         <p style="text-align:right;font-size:18px">Credits: <a href="https://doi.org/10.1016/j.cub.2016.02.033">Chitwood and Sinha (2016)</a></p>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <p style="text-align:center;font-size:24px"><strong>Landmark-based morphometrics (GMM)</strong></p>
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/chitwood_2021_fig-004_1.jpg" alt = "Website icon" style="width:480px;"/>
#         <p style="text-align:right;font-size:18px">Credits: <a href="https://doi.org/10.1002/ppp3.10157">Chitwood (2020)</a></p>
#     </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# # We need something more robust for more diverse data

# %%
display.display(widgets.HBox([video5,video6,video7,video8]))

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
# # Topological Data Analysis (TDA)
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/S019_L0_1.gif" alt = "barley" style="width:250px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Raw Data</strong></p>
#         <ul style="font-size:20px">
#           <li> X-ray CT </li>
#           <li> Point clouds </li>
#           <li> Time series </li>
#         <ul>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/ecc_X.gif" alt = "Website icon" style="width:330px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Topological Summary</strong></p>
#         <ul style="font-size:20px">
#           <li> Euler Characteristic </li>
#           <li> Persistence diagrams </li>
#           <li> Mapper/Reeb graphs </li>
#         <ul>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src="https://www.egr.msu.edu/~amezqui3/barley/figs/svm_mds_ect.gif" alt="NSF Logo" style="width:350px">
#         <p style="text-align:center;font-size:30px"><strong>Analysis</strong></p>
#         <ul style="font-size:20px">
#           <li> Statistics </li>
#           <li> Machine learning </li>
#           <li> Classification/prediction </li>
#         <ul>
#     </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# - Topological summaries can be more than just numbers
# - The featurization step can be as non-trivial as we want it to be

# %% [markdown]
# # Main goal of TDA
#
# Provide
# - **Quantifiable**
# - **Comparable**
# - **Robust**
# - **Concise**
# summaries of the shape of data
#
# ## Shape is data, and data is shape
#
# <img src=https://www.egr.msu.edu/~amezqui3/arabidopsis/figs/PFig1.png width="650">
#
# Credits: [Daniel Park](https://orcid.org/0000-0003-2783-530X)

# %% [markdown]
# # What is topology anyway?

# %% [markdown]
# ## Topology for non-topologists
#
# - Topology thinks of the world as if made out of **clay**.
#
# - The shape of an object does not change if we stretch it, shrink it or mold it smoothly
#
# - However, breaking, cutting, and pasting however are not smooth operations, and alter the shape of objects.

# %% [markdown]
# <img src=https://www.egr.msu.edu/~amezqui3/arabidopsis/figs/arabidopsis_topology.jpg width="1300">
#
# - An _Arabidopsis thaliana_ leaf under different smooth transformations

# %% [markdown]
# ### A coffee mug and a bagel are topologically equivalent
#
# <img src=https://upload.wikimedia.org/wikipedia/commons/2/26/Mug_and_Torus_morph.gif width="600">
#
# Credits: [Wikimedia commons](https://commons.wikimedia.org/wiki/File:Mug_and_Torus_morph.gif)

# %% [markdown]
# ### A cow and a ball can also be topologically equivalent
#
# - We have to assume that the cow keeps its nostrils, ears, and mouth shut
#
# <img src=https://www.egr.msu.edu/~amezqui3/tda/figs/spherical_cow width="600">

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
# ## Some basic language clarifications: hollows do matter
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/Red_circle.svg/1200px-Red_circle.svg.png" alt = "barley" style="width:280px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Circle</strong></p>
#         <br>
#         <img src = "https://wallazee.global.ssl.fastly.net/images/dynamic/items/145-1024.png" alt = "barley" style="width:280px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Sphere</strong></p>
#         <ul style="font-size:20px">
#           <li> Hollow/empty inside </li>
#         <ul>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.publicdomainpictures.net/pictures/310000/velka/red-circle.png" alt = "Website icon" style="width:280px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Disc</strong></p>
#         <br>
#         <img src = "https://pngimg.com/uploads/billiard/billiard_PNG85027.png" alt = "Website icon" style="width:280px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Ball</strong></p>
#         <ul style="font-size:20px">
#           <li>Solid inside</li>
#         <ul>
#     </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# # Bringing topology to real-life settings
#
# ## Topological Data Analysis

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
#
# # Two basic ingredients to do TDA
#
# ## Data points / Network / Image &rarr; Building blocks &rarr; Simplices
#
# ### Simplices &rarr; Complexes
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/simplicial_complex.jpg" alt = "barley" style="width:330px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Simplicial complex</strong></p>
#         <ul style="font-size:20px">
#           <li> 3 connected components </li>
#           <li> 1 loop </li>
#           <li> 1 void </li>
#         <ul>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/cubical_complex_example.jpg" alt = "Website icon" style="width:280px;"/>
#         <p style="text-align:center;font-size:30px"><strong>Cubical complex</strong></p>
#         <ul style="font-size:20px">
#           <li> 2 connected components </li>
#           <li> 3 loops </li>
#           <li> 1 void </li>
#         <ul>
#     </td>
#   </tr>
# </tbody>
# </table>
#
# - TDA seeks to describe the **shape** of data based on important **topological features**:
#     - Connected components
#     - Loops
#     - Voids
#
# - Their count is referred to as **Betti numbers**, $\beta_0, \beta_1, \beta_2$.

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
# ## Filter function: point / pixel &rarr; real number
#
# - A complex is built by adding low-valued simplices first
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/eigcurv_filter.gif" alt = "barley" style="width:230px;"/>
#         <p style="text-align:center;font-size:20px"><strong>Curvature</strong></p>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.egr.msu.edu/~amezqui3/barley/figs/eccentricity_filter.gif" alt = "Website icon" style="width:230px;"/>
#         <p style="text-align:center;font-size:20px"><strong>Eccentricity</strong></p>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src="https://www.egr.msu.edu/~amezqui3/barley/figs/gaussian_density_filter.gif" alt="NSF Logo" style="width:230px">
#         <p style="text-align:center;font-size:20px"><strong>Gaussian Density</strong></p>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src="https://www.egr.msu.edu/~amezqui3/barley/figs/vrips_ver2.gif" alt="NSF Logo" style="width:230px">
#         <p style="text-align:center;font-size:20px"><strong>Vietoris-Rips</strong></p>
#     </td>
#   </tr>
# </tbody>
# </table>
#
# - TDA seeks to describe how the topological **features** (number of connected components, loops, voids) **change** as we increase the filter values.

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
# ## Example 1
#
# ### Detect holes &rarr; detect cancerous tissue
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://ars.els-cdn.com/content/image/1-s2.0-S1361841518302688-gr1.jpg" alt = "barley" style="width:700px;"/>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://ars.els-cdn.com/content/image/1-s2.0-S1361841518302688-gr2_lrg.jpg" alt = "Website icon" style="width:680px;"/>
#         <p style="text-align:center;font-size:18px">Credits: <a href="https://doi.org/10.1016/j.media.2019.03.014">Qaiser <em> et al.</em> (2019)</a></p>
#     </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
# ## Example 2
#
# ### Detect holes &rarr; detect reassortment and horizontal evolution
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.pnas.org/content/pnas/110/46/18566/F1.large.jpg" alt = "barley" style="width:700px;"/>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.pnas.org/content/pnas/110/46/18566/F2.large.jpg" alt = "Website icon" style="width:680px;"/>
#         <p style="text-align:center;font-size:18px">Credits: <a href="https://doi.org/10.1073/pnas.1313480110">Chan <em> et al.</em> (2013)</a></p>
#     </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:left;vertical-align:top}
# </style>
#
# ## Example 3
#
# ### Detect holes &rarr; detect open and closed conformations
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.degruyter.com/document/doi/10.1515/sagmb-2015-0057/asset/graphic/j_sagmb-2015-0057_fig_001.jpg" alt = "barley" style="width:650px;"/>
#         <img src = "https://www.degruyter.com/document/doi/10.1515/sagmb-2015-0057/asset/graphic/j_sagmb-2015-0057_fig_012.jpg" alt = "barley" style="width:650px;"/>
#     </td>
#     <td class="tg-baqh" style="text-align:left">
#         <img src = "https://www.degruyter.com/document/doi/10.1515/sagmb-2015-0057/asset/graphic/j_sagmb-2015-0057_fig_010.jpg" alt = "Website icon" style="width:650px;"/>
#         <p style="text-align:center;font-size:18px">Credits: <a href="https://doi.org/10.1515/sagmb-2015-0057">Kovacev-Nikolic <em> et al.</em> (2016)</a></p>
#     </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Example 4
#
# ### Filter by height &rarr; detect panicle structure
#
# <img src=https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-3-030-20867-7_7/MediaObjects/484957_1_En_7_Fig1_HTML.png width="500">
#
# Credits: [Chitwood _et al_ (2019)](https://doi.org/10.1007/978-3-030-20867-7_7)

# %% [markdown]
# ## Example 5
#
# ### Filter by heteroblasty &rarr; detect passiflora leaf shape
#
# <img src=https://www.egr.msu.edu/~amezqui3/tda/figs/g86.png width="650">
#
# Credits: Percival _et al_ (in preparation)

# %% [markdown]
# # Advertisement
#
# ## More content and references
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/amezquita_etal_2020.png width="1000">
#
# Amézquita et al. (2020) The shape of things to come: Topological data analysis and biology, from molecules to organisms. _Developmental Dynamics_ **249**(9) pp. 816-833. [DOI:10.1002/dvdy.175](https://doi.org/10.1002/dvdy.175)

# %% [markdown]
# ## Applications of TDA to biology
#
# - **Structural biology.** A diagram of RNA secondary structure (left; solid lines covalent bonds, dashed lines hydrogen bonds). Increasing radii of vertices (middle, right; blue points) are used to visualize filtration on Euclidean distance. As radii merge, connected components die. Purple lines indicate the formation of loops that eventually fill in as the radius threshold increases.
# - **Evolution.** A plot showing the genetic distance of samples (left). As radius threshold value increases (middle, right) the birth and death of connected components (blue) represent vertical evolution (a tree) while that of loops (purple) horizontal evolution events (such as hybridization, gene transfer, or recombination; modified from [Chan et al (2013)](https://doi.org/10.1073/pnas.1313480110).
# - **Cellular architecture.** Modification of a part of the original Gleason guide to prostate cancer changes in cellular architecture (left). Nuclei (blue) increase in radius (middle, right) and connected components (blue) and loops (purple) are born and die.
# - **Branching architecture.** A theoretical tree where the filter is the geodesic distance to the base (blue). Branching tips are separate connected components that merge as the filter progresses to the base of the tree (left to right).
# - **Mapper.** Point cloud of a hand where the filter is the axes from the wrist to fingertips (left). Cover intervals (bars on top of the color scale) and their overlap (gray bars) divide points into bins (middle). Points that cluster together over each cluster are assigned to a vertex, and if the points are shared between clusters in an overlap, then they are assigned to an edge connecting the corresponding vertices (modified from [Lum et al (2013)](https://doi.org/10.1038/srep01236).)

# %% [markdown]
# # Plenty of places to get started

# %% [markdown]
# # Plenty of software and resources
#
# It's hard to keep up with the software development of TDA these days.
#
# I have personally used the following, but **keep in mind** that there are many more software options out there.
#
# - [SciKitTDA](https://scikit-tda.org/) (python) by Nataniel Saul and Chris Tralie
# - [Ripser](https://github.com/Ripser/ripser) (C++) by Ulrich Bauer
# - [GUDHI](https://gudhi.inria.fr/) (python) developed at INRIA
# - [Giotto-tda](https://github.com/giotto-ai/giotto-tda) (python) developted at EPFL
# - [TDA](https://cran.r-project.org/web/packages/TDA/index.html) (R) by Brittany T. Fasy, Jisu Kim, Fabrizio Lecci, and Cl&eacute;ment Maria
#
# As far as I know, these five projects remain active and are updated every once in a while.

# %% [markdown]
# ## More software and resources
#
# An **incomplete** list. It's hard to keep up with the software development of TDA these days.
#
# **Warning:** some of the options below are no longer active, or haven't been updated in a while.
#
# ### C/C++
#
# - [Cubicle](https://bitbucket.org/hubwag/cubicle/src/master/) by Hubert Wagner, Teresa Heiss, Georg Osang
# - [Chunky Euler](https://bitbucket.org/hubwag/chunkyeuler/src/master/) by Teresa Heiss and Hubert Wagner
# - [HomcCube](https://i-obayashi.info/software.html) by Ippei Obayashi.
# - [CubicalRipser](https://github.com/orgs/CubicalRipser/repositories) by Takeki Sudo and Kazushi Ahara
# - [DIPHA](https://github.com/DIPHA/dipha) by Ulrich Bauer and Michael Kerber
# - [diamorse](https://github.com/AppliedMathematicsANU/diamorse) developed at The Australian National University.
# - [Perseus](http://people.maths.ox.ac.uk/nanda/perseus/) by Vidit Nanda
# - [Dionysus2](https://www.mrzv.org/software/dionysus2/) (python bindings available) by Dimitry Morozov
# - [CHomP](https://github.com/shaunharker/CHomP) by Shaun Harker
# - [Hera](https://bitbucket.org/grey_narn/hera) by Michael Kerber, Dmitriy Morozov, and Arnur Nigmetov
# - [PHAT](https://bitbucket.org/phat-code/phat) (python bindings available) by Ulrich Bauer, Michael Kerber, Jan Reininghaus, Hubert Wagner, and Bryn Keller
# - [Topology ToolKit](https://topology-tool-kit.github.io/) by Julien Tierny, Guillaume Favelier, Joshua Levine, Charles Gueunet, and Micha&euml;l Michaux
# - [Persistence Landscape Toolbox](https://www.math.upenn.edu/~dlotko/persistenceLandscape.html) by Pawel Dlotko&#8203;
#
# ### R
#
# - [SimplexTree](https://github.com/peekxc/simplextree) by Matt Piekenbrock and Corey Brunson
# - [TDAstats](https://github.com/rrrlw/TDAstats) by Raoul R. Wadhwa, Drew F.K. Williamson, Andrew Dhawan, and Jacob G. Scott
# - [Mapper](https://github.com/peekxc/Mapper) by Matt Piekenbrock and Corey Brunson
# - [TDAMapper](https://github.com/paultpearson/TDAmapper) by Paul Pearson, Daniel M&uuml;ellner, and Gurjeet Singh
# - [R scripts for TDA](https://people.clas.ufl.edu/peterbubenik/intro-to-tda/) by Peter Bubenik and Leo Betthauser
#
# ### Python
#
# - [Teaspoon](https://lizliz.github.io/teaspoon/) by Liz Munch, Firas Khasawneh, Audun Myers, Melih Yesilli, and Sarah Tymochko
# - [Python Mapper](http://danifold.net/mapper/index.html) by Daniel M&uuml;llner and Aravindakshan Babu
# - [statmapper](https://github.com/MathieuCarriere/statmapper) by Mathieu Carrière
#
# ### Other
#
# - [CliqueTop](https://github.com/nebneuron/clique-top) (Matlab) by Chad Giusti
# - [Eirene](http://gregoryhenselman.org/eirene/index.html)(Julia) by Greg Henselman
# - [JavaPlex](https://github.com/appliedtopology) (Java) by Andrew Tausz, Mikael Vejdemo-Johansson and Henry Adams
# - [Simplicial complexes for Julia](https://github.com/nebneuron/Simplicial) by Alex Kunin and Vladimir Itskov
# - [SimBa](http://web.cse.ohio-state.edu/~dey.8/SimBa/Simba.html) and [SimPer](http://web.cse.ohio-state.edu/~dey.8/SimPers/Simpers.html) by Tamal K Dey, Fengtao Fan, Dayu Shi, and Yusu Wang

# %% [markdown]
# # Plenty of tutorials available: theory + applications
#
#
# ### TDA tutorial based on Liz Munch's work
#
# - AMS TDA Workshop for Network Science. [Github repo](https://github.com/lizliz/TDA-Python-Workshop-JMM21).

# %%
display.YouTubeVideo('SbsvM4Gcbl0', width=800, height=500)

# %% [markdown]
# ## AATRN + WinCompTop TDA [tutorial-a-thon](https://sites.google.com/view/aatrn-tutorial-a-thon) material
#
# <img src=https://www.egr.msu.edu/~amezqui3/tda/figs/aatrn_tutorialathon.png width="400">
#
# - Much more material at the [AATRN YouTube Channel](https://www.youtube.com/c/AppliedAlgebraicTopologyNetwork)
#
# ### Community-sourced tutorials on both theory and applications
#
# - [Spring 2021](https://www.youtube.com/playlist?list=PL4kY-dS_mSmJabQiM2ySRSUusbvmdIxBt): 39 videos
# - [Fall 2021](https://www.youtube.com/playlist?list=PL4kY-dS_mSmIF4fw9HGh1K-ItQDeQREyP): 21 videos

# %%
display.display(widgets.HBox([video11,video13]))
display.display(widgets.HBox([video12,video14]))

# %% [markdown]
# # Go to [AATRN](https://www.aatrn.net/) and join the mailing list!
#
# - Tutorials
# - Events
# - AAT(ea)RN &rarr; informal, virtual meet-ups
# - Look for TDA people in your area
#
# # Join the [slack](geometry-topology-ml.slack.com)! Geometry & Topology in ML
#
# - Active but not overwhelming
# - Friendly nature to new people
#
# <img src=https://www.egr.msu.edu/~amezqui3/tda/figs/gtml_slack.png width="600">

# %% [markdown]
# # A word on computing difficulties
#
# - Despite huge advancements in TDA software, we still face considerable **computational bottlenecks**.
# - Most of the software has trouble dealing with large, high-resolution images (like X-ray CT scans.)
#
#
# - Check [Otter et al. (2017)](https://doi.org/10.1140/epjds/s13688-017-0109-5) for a general review on TDA software.

# %% [markdown]
# - Although, this code will be run live

# %% [markdown]
# # Let's focus on a particular method

# %% [markdown]
# # The Euler Characteristic $\chi$
#
# - Topological **invariant**: Objects with the same topological features will share the **same** Euler Characteristic
#
# $$\chi = \#({\rm Vertices}) - \#({\rm Edges}) + \#({\rm Faces})$$
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/euler_characteristic_2.png width="750">
#
#
# - Euler-Poincaré formula:
#
# $$\begin{align}
# \chi &= \#(\text{Connected Components}) - \#({\rm Loops}) + \#({\rm Voids})\\
# &= \beta_0 - \beta_1 + \beta_2
# \end{align}$$

# %% [markdown]
# # But the Euler Characteristic might be too simple
#
# - We are unable to distinguish a pyramid from a prism based on the Euler characteristic alone.
#
#
# - Even worse, topologically different spaces _might_ have the same Euler characteristic.
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/euler_characteristic_variety.jpg width="1800">

# %% [markdown]
# # The Euler Characteristic Curve (ECC)
#
# - Pick a **direction**. (Directional filter)
#
# - Slice the image into a fixed number of slices (**thresholds**) along the initial direction.
#
# - Keep track of **changes** in $\chi$ as we reconstruct the image, one slice at a time.
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/ecc_ver2.gif width="1300">

# %% [markdown]
# ## The number of thresholds matter
#
# - Finer slices in general will capture more nuanced changes in the Euler characteristic
# - However, finer slices will produce longer vectors which can be problematic (see [curse of dimensionality](https://en.wikipedia.org/wiki/Curse_of_dimensionality))
#
# <img src=https://www.egr.msu.edu/~amezqui3/tda/figs/thresholds_ecc_fern.jpg width="1300">

# %% [markdown]
# # The Euler Characteristic Transform (ECT)
#
# - Perform the ECC with **all possible** directions
#
#
# - **Concatenate** all resulting ECCs
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/ect_ver2.gif width="1600">

# %% [markdown]
# # Importance of the ECT
#
# - **Computationally extremely efficient** (as you'll see in the examples below)
#
#
# - **Mathematically** speaking, the ECT is a **sufficient** shape statistic
#
#
# - _Caveat:_ We do need an **infinite** number of directions for the math to hold.

# %% [markdown]
# # Importance of the ECT (more details)
#
# - **Computationally extremely efficient** (as you'll see in the examples below)
# - We can compute an ECT in $O\,(ND)$ time, with $N$ vertices and $D$ directions.
# - We followed a binsort strategy as discussed by [Richardson and Werman (2014)](https://doi.org/10.1016/j.patrec.2014.07.001).
#
#
# - As mathematically proved [Turner et al. (2014)](https://doi.org/10.1093/imaiai/iau011), the ECT is **injective**!
# - Different shapes will have different ECTs and viceversa
# - The ECT is a **sufficient** shape statistic
#
#
# - _Caveat:_ Turner et al do need an **infinite** number of directions for the math to hold.
# - Math also works in more **dimensions**: [Ghrist et al. (2018)](https://doi.org/10.1007/s41468-018-0017-1).
# - Advances in **reducing** the number of directions: [Curry et al. (2018)](https://arxiv.org/abs/1805.09782)
# - **Reconstruct** the original shape based solely on the ECT: [Fasy et al. (2019)](https://arxiv.org/abs/1912.12759), [Betthauser (2018)](https://people.clas.ufl.edu/peterbubenik/files/Betthauser_Thesis.pdf)

# %% [markdown]
# # Let's finally see some code!
#
# Please check the `README` file at the start of the repository to know how to install `demeter`

# %%
# Basic imports that should come with all official python distributions
import importlib
import time

# Standard python imports that should come with anaconda
# Else, they can be easily pip installed
# pip install numpy pandas scipy matplotlib ipython ipywidgets
import numpy as np
import pandas as pd

import scipy.ndimage as ndimage
import scipy.spatial.distance as distance

import warnings
warnings.filterwarnings( "ignore")
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec

# A comfy way to import/export TIFF files as numpy.arrays
# pip install tifffile
import tifffile as tf

# %% [markdown]
# ## Our implementation of the Euler Characteristic Transform
#
# * download the code with:
# ```shell
# git clone https://github.com/amezqui3/demeter/
# ```
# * move to the directory:
# ```shell
# cd demeter
# ```
# * install with:
# ```shell
# pip install -e .
# ```
#
# * the `-e` flag is optional. It stands for _editable_, so changes in the source python files will be immediately reflected whenever importing the package.
#
# The package can then be imported in a python shell with:
# ```shell
# import demeter
# ```
#
# ## Alternative
#
# Simply copy this notebook in the root folder, `demeter`.
# - The same folder where `README.md` is located **not** where you see `.py` files.

# %%
# Our implementation of the Euler Characteristic Transform

# See the README in the repository to install `demeter`

import demeter.euler as euler
import demeter.directions as dirs
import demeter.misc as misc

# %% [markdown]
# # Step 1: Load the data
#
# **Step 0**: Clean and wrangle the data so that it is a numpy 2D/3D array.
#
# - From now on by pixel we mean nonzero-valued pixel
# - We'll treat zero-valued pixels as nonexistent.

# %%
leaf_file = '../example_data/leafbw.tif'

#If running from colab, uncomment the following line
#leaf_file = 'gdrive/My Drive/tda_workshop/example_data/leafbw.tif'

leaf_img = tf.imread(leaf_file)
leaf_img[leaf_img > 0] = 1

fig, ax = plt.subplots(1,2,figsize=(20,6))
ax[0].imshow(leaf_img.T, cmap='gray', origin='lower');
ax[0].plot([200,200,250,250,200], [280,310,310,280,280], c='red', lw=4);
ax[1].imshow(leaf_img.T[280:310, 200:250], cmap='gray', origin='lower');

# %% [markdown]
# # Step 2: Complexify the image
#
# - We'll work with the dual cubical complex: the pixels will be treated as vertices.
# - This complex corresponds to the 4-neighbor 2D digital topology.
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/binary_to_cubical_complex_textless.png width="900">
#
# $$\begin{align}
# \chi &= 20 \;\mathrm{ vertices } - 22 \;\mathrm{edges} + 3 \;\mathrm{faces}\\
# &= 2\;\mathrm{connected\; components} - 1\;\mathrm{loop} + 0\;\mathrm{voids}
# \end{align}
# $$
#
#
# - The code works in linear time with respect to the number of image pixels/voxels

# %% [raw]
# importlib.reload(euler)
#
# tic = time.perf_counter()
# leaf = euler.CubicalComplex(leaf_img).complexify(center=False)
# toc = time.perf_counter()
#
# print("Complexify in {:.4f} seconds.\n\nCubical complex made of:".format(toc-tic))
#
# leaf.summary();

# %%
for i in range(len(leaf.cells)):
    print('{}-dim cells summarized in a {} numpy.array'.format(i, leaf.cells[i].shape))
    for j in range(6):
        print(j, '\t', leaf.cells[i][j,:])
    print('---')
# Out:
# 0-dim cells summarized in a (53832, 2) numpy.array
# 0 	 [  8 269]
# 1 	 [  8 270]
# 2 	 [  9 268]
# 3 	 [  9 269]
# 4 	 [  9 270]
# 5 	 [  9 271]
# ---
# 1-dim cells summarized in a (99196, 2) numpy.array
# 0 	 [0 1]
# 1 	 [0 3]
# 2 	 [1 4]
# 3 	 [2 3]
# 4 	 [2 7]
# 5 	 [3 4]
# ---
# 2-dim cells summarized in a (45167, 4) numpy.array
# 0 	 [0 1 3 4]
# 1 	 [2 3 7 8]
# 2 	 [3 4 8 9]
# 3 	 [ 4  5  9 10]
# 4 	 [ 5  6 10 11]
# 5 	 [ 7  8 14 15]
# ---

# %% [markdown]
# ### More details on complexifying images in [`jupyter/07_complexify_binary_image.ipynb`](https://github.com/amezqui3/demeter/blob/main/jupyter/07_complexify_binary_image.ipynb) in the [github repo](https://github.com/amezqui3/demeter/).

# %% [markdown]
# # Step 3: Choose directions

# %%
circle_dirs = dirs.regular_directions(24, dims=leaf.ndim)
plt.figure(figsize=(6,6))
plt.axhline(0, color='red')
plt.axvline(0, color='red')
plt.plot(circle_dirs[:,0], circle_dirs[:,1], marker='^', ms=20, lw=3)
plt.axis('equal');

# %% [markdown]
# ### Directions on 3D can be trickier. Check [`jupyer/08_sphere_directions.ipynb`](https://github.com/amezqui3/demeter/blob/main/jupyter/08_sphere_directions.ipynb) in the [github repo](https://github.com/amezqui3/demeter) for more details.

# %% [markdown]
# # Step 4: Compute the Euler Characteristic Curve (ECC) along one direction

# %%
## Plot functions so that we do not clutter the next slides/cells

def plot_ecc(CComplex, filtration, T, title='title', ylim=(-30,30)):
    fig, ax = plt.subplots(2,3, figsize=(15,6), facecolor='snow')
    fig.suptitle('ECC for filter: {}'.format(title), fontsize=30)
    for j in range(2):
        for k in range(3):
            ax[j,k].plot((0,0),ylim, c='white')
            ax[j,k].set_ylabel('Euler characteristic', fontsize=12)
            ax[j,k].set_xlabel('Sublevel set', fontsize=12)
            ax[j,k].plot(CComplex.ECC(filtration, T[3*j+k]), 
                         lw=3, label = 'T = {}'.format(T[3*j+k]))
            ax[j,k].legend(fontsize=14)
            ax[j,k].set_facecolor('gainsboro')
    fig.tight_layout()

def plot_ecc_filtration(CComplex, filtration, T, TT=32, title='title', ydot=(-30,30), direction=None):
    bins = np.linspace(np.min(filtration), np.max(filtration), TT+1)
    indices = np.digitize(filtration, bins=bins, right=False)

    fig = plt.figure(constrained_layout=True, figsize=(20,7), facecolor='snow')
    gs = fig.add_gridspec(2,4)
    for j in range(2):
        for k in range(2):
            ax = fig.add_subplot(gs[j,k])
            ax.plot((0,0),ydot, c='white')
            ax.set_ylabel('Euler characteristic', fontsize=12)
            ax.set_xlabel('Sublevel set', fontsize=12)
            ax.plot(CComplex.ECC(filtration, T[2*j+k]), lw=5, label = 'T = {}'.format(T[2*j+k]))
            ax.legend(fontsize=20)
            ax.set_facecolor('gainsboro')
    ax = fig.add_subplot(gs[:,2:])
    scatter = ax.scatter(*CComplex.cells[0].T, 
                         s=0.2, c=indices, cmap='plasma', label='T = {}'.format(TT))
    ax.set_facecolor('whitesmoke')
    if direction is not None:
        start = 0.5*(np.max(CComplex.cells[0], axis=0) + np.min(CComplex.cells[0], axis=0))
        norm = 0.5*np.linalg.norm(start-np.max(leaf.cells[0], axis=0))
        #start += 0.5*norm*direction
        end = norm*direction
        ax.arrow(*start, *end, head_width=30, head_length=20, width=4, color='blue')
        
    ax.legend(fontsize=20, markerscale=30)
    cbar = plt.colorbar(scatter, ax=ax, orientation='horizontal', pad=0.01);
    ax.axis('equal');
    cbar.ax.tick_params(labelsize=20)

    fig.suptitle('ECC for filter: {}'.format(title), fontsize=30);

# %%
T = [8,16,32,64,128]
i = 21
direction = circle_dirs[i, :] 
heights = np.sum(leaf.cells[0]*direction, axis=1)
plot_ecc_filtration(leaf, heights, T, title=np.around(direction,2), ydot=(1,20), direction=direction)

# %%
fig, axs = plt.subplots(2,3, figsize=(24,10), sharex=True, sharey=True, facecolor='whitesmoke')

axs = np.atleast_1d(axs).ravel()
filtration = np.sum(leaf.cells[0]*direction, axis=1)
T = [2, 4, 8, 16, 32, 64, 128]
start = 0.5*(np.max(leaf.cells[0], axis=0) + np.min(leaf.cells[0], axis=0))
norm = np.zeros(2) + 100
end = norm*direction

for i,ax in enumerate(axs):
    TT = T[i]
    bins = np.linspace(np.min(filtration), np.max(filtration), TT+1)
    indices = np.digitize(filtration, bins=bins, right=False)
    indices[indices > TT] = TT
    
    scatter = ax.scatter(*leaf.cells[0].T, 
                         s=0.2, c=indices, cmap='inferno', label='T = {}'.format(TT))
    ax.set_facecolor('gainsboro')
    ax.margins(0,0)
    ax.arrow(*start, *end, head_width=30, head_length=20, width=4, color='blue')

    ax.legend(fontsize=20, markerscale=30, loc='upper right')
    ax.axis('image');
    ax.set_xticklabels(''); ax.set_yticklabels('')
    ax.tick_params(bottom=False, left=False)

fig.tight_layout();
#filename = '/home/ejam/documents/webpage/tda/figs/thresholds_ecc_fern.jpg'
#plt.savefig(filename, format='jpg', dpi=96, bbox_inches='tight', pil_kwargs={'optimize':True})

# %% [markdown]
# # Step 5: Concatenate to get the Euler Characteristic Transform (ECT)

# %%
t = 32
tic = time.perf_counter()
ect = leaf.ECT(circle_dirs, T=t)
toc = time.perf_counter()
print("Complex with {} vertices\n".format(len(leaf.cells[0])))
print("ECT with {} directions in {:.4f} seconds.\n{:.4f}s per direction".format(len(circle_dirs), toc-tic, (toc-tic)/len(circle_dirs)))

plt.figure(figsize=(15,2), facecolor='snow')
plt.plot(ect);
plt.title('ECT for {} directions and {} thresholds each'.format(len(circle_dirs),t), fontsize=24);
# Out:
# Complex with 53832 vertices
#
# ECT with 24 directions in 0.1567 seconds.
# 0.0065s per direction

# %% [markdown]
# ### More details on how the ECT algorithm actually works in [`jupyter/ect_computation.ipynb`](https://github.com/amezqui3/demeter/blob/main/jupyter/09_ect_computation.ipynb) in the [github repo](https://github.com/amezqui3/demeter/).

# %% [markdown]
# # Same run with 3D data
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/S017_L0_seed_10_0.gif width="300">

# %%
seed_file = '../example_data/seed_8_0_p7_d4_t120_o7_e1_g3.tif'

#If running from colab, uncomment the following line
#leaf_file = 'gdrive/My Drive/tda_workshop/example_data/seed_8_0_p7_d4_t120_o7_e1_g3.tif'

seed_img = tf.imread(seed_file)
seed_img[seed_img > 0] = 1

tic = time.perf_counter()
seed = euler.CubicalComplex(seed_img).complexify()
toc = time.perf_counter()

print("Complexify in {:.4f} seconds.\n\nCubical complex made of:".format(toc-tic))
seed.summary();
# Out:
# Complexify in 2.2297 seconds.
#
# Cubical complex made of:
# 53631	vertices
# 154741	edges
# 148746	squares
# 47635	cubes
# ----
# Euler Characteristic: 1

# %%
max_vox = misc.find_tip(seed.cells[0], 2,1,0)
seed_coords,_, _, _,_ = misc.rotateSVD(seed.cells[0], max_vox)

misc.plot_3Dprojections(seed_coords, 'Sample barley seed')

# %%
sphere_dirs = dirs.regular_directions(128)
title = 'Regular placement: {}'.format(len(sphere_dirs))
misc.plot_3Dprojections(sphere_dirs, title, markersize=12)

# %%
T = [4,8,16,32,48,64]
i = 0
direction = sphere_dirs[i,:]
heights = np.sum(seed_coords*direction, axis=1)

plot_ecc(seed, heights, T, title=np.around(direction,2))

# %%
t = 16
tic = time.perf_counter()
ect = seed.ECT(sphere_dirs, T=t, verts=seed_coords)
toc = time.perf_counter()
print("Complex with {} vertices\n".format(len(seed_coords)))
print("ECT with {} directions in {:.4f} seconds.\n{:.4f}s per direction".format(len(sphere_dirs), toc-tic, (toc-tic)/len(sphere_dirs)))

plt.figure(figsize=(15,2))
plt.plot(ect); 
plt.title('ECT for {} directions and {} thresholds each'.format(len(sphere_dirs),t), fontsize=24);
# Out:
# Complex with 53631 vertices
#
# ECT with 128 directions in 2.0780 seconds.
# 0.0162s per direction

# %% [markdown]
# # Not limited to just directional filters

# %%
orange_file = '../example_data/orange_blur.tif'

#If running from colab, uncomment the following line
#leaf_file = 'gdrive/My Drive/tda_workshop/example_data/orange_blur.tif'

orange_img = tf.imread(orange_file)

fig, ax = plt.subplots(1,2,figsize=(20,6))
show = ax[0].imshow(orange_img, cmap='gray');
cbar = plt.colorbar(show, ax=ax[0])
cbar.ax.tick_params(labelsize=12)
ax[0].plot([250,250,300,300,250], [260,310,310,260,260], c='red', lw=4)
show = ax[1].imshow(orange_img[260:310, 250:300], cmap='gray');
cbar = plt.colorbar(show, ax=ax[1], orientation='vertical');
cbar.ax.tick_params(labelsize=12);
# Out:
# Shaped series: series shape does not match page shape

# %%
tic = time.perf_counter()
orange = euler.CubicalComplex(orange_img).complexify()
toc = time.perf_counter()

print("Complexify in {:.4f} seconds.\n\nCubical complex made of:".format(toc-tic))
orange.summary();
# Out:
# Complexify in 6.9966 seconds.
#
# Cubical complex made of:
# 303323	vertices
# 605401	edges
# 302079	squares
# ----
# Euler Characteristic: 1

# %%
T = [16, 32, 64, 128, 256, 512]
i = 2
direction = circle_dirs[i, :]
heights = np.sum(orange.cells[0]*direction, axis=1)
heights = orange.img[orange.img > 0]
title=np.around(direction,2)

#ylim = (0,3)
ylim = (0,200)
plot_ecc_filtration(orange, heights, T, title=title, ydot=ylim)

# %%
t = 32
tic = time.perf_counter()
ect = orange.ECT(circle_dirs, T=t)
toc = time.perf_counter()
print("Complex with {} vertices\n".format(len(orange.cells[0])))
print("ECT with {} directions in {:.4f} seconds.\n{:.4f}s per direction".format(len(circle_dirs), toc-tic, (toc-tic)/len(circle_dirs)))
 
plt.figure(figsize=(15,2))
plt.plot(ect);
plt.title('ECT for {} directions and {} thresholds each'.format(len(circle_dirs), t), fontsize=24);
# Out:
# Complex with 303323 vertices
#
# ECT with 24 directions in 0.9558 seconds.
# 0.0398s per direction

# %% [markdown]
# ## Even more filters

# %%
def radial_distance(coords):
    return np.sqrt(np.sum(coords**2, axis=1))
def distance_transform(img):
    dtc = ndimage.distance_transform_cdt(img, metric='taxicab')
    return dtc[img > 0]

# %%
T = [4,8,16,32]
filtration = radial_distance(leaf.cells[0]) 
ylim = (0,12)
#T = [4,8,16,32]
filtration = distance_transform(leaf.img)
#ylim = (-10,15)

plot_ecc_filtration(leaf, filtration, T, TT=16, ydot=ylim)

# %% [markdown]
# # What next?

# %% [markdown]
# - Every shape can be translated to a vector of topological features
# - You can try to do standard statistics and data analysis
#     - Clustering
#     - Classification
#     - Regression
#     - Much more!

# %% [markdown]
# # Be aware of the curse of dimensionality
#
# <img src=https://www.egr.msu.edu/~amezqui3/barley/figs/curse_of_dimensionality.png width="700">
#
# - The ECT produces extremely long (high-dimensional) vectors
# - Long vectors can distort regressions and classifications
# - It is important to do dimension reduction first
#     - PCA
#     - Nonlinear PCA
#     - t-SNE
#     - etc

# %% [markdown]
# ## Go crazy!
#
# - Experiment with different number of directions
# - And different ways to define directions
#
#
# - What other filter functions can you think of?

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:white;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
#
# </style>
#
# # Thank you!
#
# - Joint work with [Dan Chitwood](https://dhchitwood.wixsite.com/morphologylab/publications) and [Liz Munch](http://www.elizabethmunch.com/) at CMSE/Horticulture/Math @ Michigan State University
# - Image processing/computational tips from [Tim Ophelders](https://www.win.tue.nl/~tophelde/)
# - X-ray CT scans done by [Michelle Quigley](https://www.canr.msu.edu/people/michelle-quigley)
# - Barley seeds provided by [Dan Koenig](https://koeniglab.com/) and [Jacob Landis](https://jacoblandis.com/)
# - Citrus provided by [Danelle Seymour](https://www.seymour-lab.com/)
# - Fern leaf 2D scan courtesy of [Rebecca Dikow](https://datascience.si.edu/people/dr-rebecca-dikow) and [Alexander White](http://www.alexwhitebiology.com/).
#
# <table class="tg">
#
# <tbody>
#   <tr>
#     <td class="tg-baqh">
#         <img src = "https://evacenteno.com/wp-content/uploads/2015/08/icon-blue-email-294x300.png" alt = "email icon" style="width:30px;"/>
#         <a href="mailto:amezqui3@msu.edu">amezqui3@msu.edu</a>
#     </td>
#     <td class="tg-baqh">
#         <img src = "https://cdn2.iconfinder.com/data/icons/lightly-icons/30/globe-180.png" alt = "Website icon" style="width:30px;"/>
#         <a href="http://egr.msu.edu/~amezqui3">egr.msu.edu/~amezqui3</a>
#     </td>
#     <td>
#         <img src="https://www.nsf.gov/images/logos/NSF_4-Color_vector_Logo_thumb.jpg" alt="NSF Logo" style="width:80px">
#       </td>
#           <td>
#         <img src="https://cmse.msu.edu/sites/_cmse/assets/Image/image002.jpg" alt="MSU CMSE Logo" style="width:80px">
#       </td>
#
#   </tr>
# </tbody>
# </table>
